# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
text = """Space exploration has led to incredible scientific discoveries. From landing on the Moon to exploring Mars, humanity continues to push the boundaries of what's possible beyond our planet. These missions have not only expanded our knowledge of the universe but have also contributed to advancements in technology here on Earth. Satellite communications, GPS, and even certain medical imaging techniques trace their roots back to innovations driven by space programs."""

splitter = CharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 0,
    separator=""
)

chunk = splitter.split_text(text)

print(chunk)
# Out:
# ['Space exploration has led to incredible scientific discoveries. From landing on the Moon to explorin', "g Mars, humanity continues to push the boundaries of what's possible beyond our planet. These missio", 'ns have not only expanded our knowledge of the universe but have also contributed to advancements in', 'technology here on Earth. Satellite communications, GPS, and even certain medical imaging technique', 's trace their roots back to innovations driven by space programs.']

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import CharacterTextSplitter

# %%
loader = PyPDFLoader('avengers.pdf')

docs = loader.load()

splitter = CharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 0,
    separator=""
)

chunk = splitter.split_documents(docs)

print(chunk[1].page_content)
# Out:
# acter in the Avengers universe. Life: The
# character has a complex backstory involving personal strug

# %%
loader = PyPDFLoader('avengers.pdf')

docs = loader.load()

splitter = CharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 20, # Generally for Rag applications, chunk overlap should be 10 to 20 percent of the chunk size
    separator=""
)

chunk = splitter.split_documents(docs)

print(chunk[0].page_content)
# Out:
# Avengers Universe - Page 1
# Iron Man (Tony Stark)
# Iron Man (Tony Stark) is a prominent fictional char
