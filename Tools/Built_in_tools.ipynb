# %%
# search from the internet

from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

result = search_tool.invoke("What is top news today")
print(result)
# Out:
# When it comes to racing humans vs. robots, it really is a marathon and not a sprint. ... The satirical news site said it's rebranding right-wing pundit Alex Jones' controversial platform under a proposed licensing deal. Speed News: PM Modi Says 'Women's Reservation Bill Will Not Favour Any Party' First Day First Show News and reviews from the world of cinema and streaming. SEE ALL NEWSLETTERS ... Opinion Editorial Cartoon Columns Comment Interview Lead Letters Open Page Corrections & Clarifications ... Today's Cache Your download of the top 5 technology stories of the day. 9 hours ago - US-Iran-Israel War Live Updates: Iran refused to hold the second round of the ceasefire talks with the United States, citing Washington's "excessive demands, unrealistic expectations, constant shifts in stance, repeated contradictions, and the naval blockade of the maritime chokepoint, Strait of Hormuz. Meanwhile, Donald Trump said that the US delegation team, led by Vice President JD Vance, will arrive in Islamabad today. 14 hours ago - Top News Stories of the day, Latest News Headlines, News Specials, Breaking News and Latest India News, World current affairs & Political News all around the clock at NDTV.com.

# %%
# Runs the command on windows powershell

from langchain_community.tools import ShellTool

shell = ShellTool()

result = shell.invoke("ls")
print(result)
# Out:
# Executing command:
#  ls
# c:\Users\bathr\Desktop\Cybrom_Class_Data\SELF GenAI Projects\learn_env\Lib\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
# Built_in_tools.ipynb
