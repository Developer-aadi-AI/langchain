# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableSequence
from langchain_core.output_parsers import StrOutputParser

# %%
base_url = "http://localhost:11434"
model = "llama3.2"

llm = ChatOllama(
    base_url=base_url,
    model=model,
    temperature=0.7)

prompt1 = PromptTemplate(
    template="Write a 3 to 5 liner joke about the {topic}",
    input_variables=['topic']
    )

parser = StrOutputParser()

prompt2 = PromptTemplate(
    template="expalin this {joke}",
    input_variables=['joke']
    )

# %%
chain = RunnableSequence(prompt1 | llm | parser | prompt2 | llm | parser)

result = chain.invoke("America")
print(result)
# Out:
# I see what you did there! That's a clever play on words, using the phrase "free spirit" in a literal and figurative sense.
#
# In this joke, the Statue of Liberty is anthropomorphized, giving it human-like qualities and emotions. The punchline relies on the multiple meanings of "liberty":
#
# 1. Freedom from oppression or restriction (the statue's original purpose).
# 2. Emotional liberation or release (the idea that the statue needs to work through its feelings).
#
# The joke also uses a clever pun on the word "fractured," which can refer both to physical cracks in the statue and emotional turmoil.
#
# Overall, it's a lighthearted and humorous take on an iconic symbol of freedom and democracy.
